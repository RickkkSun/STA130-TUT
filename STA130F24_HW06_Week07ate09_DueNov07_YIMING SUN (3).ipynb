# %% [markdown]
# # STA130 Homework 06
#
# Please see the course [wiki-textbook](https://github.com/pointOfive/stat130chat130/wiki) for the list of topics covered in this homework assignment, and a list of topics that might appear during ChatBot conversations which are "out of scope" for the purposes of this homework assignment (and hence can be safely ignored if encountered)

# %% [markdown]
# <details class="details-example"><summary style="color:blue"><u>Introduction</u></summary>
#
# ### Introduction
#
# A reasonable characterization of STA130 Homework is that it simply defines a weekly reading comprehension assignment.
# Indeed, STA130 Homework essentially boils down to completing various understanding confirmation exercises oriented around coding and writing tasks.
# However, rather than reading a textbook, STA130 Homework is based on ChatBots so students can interactively follow up to clarify questions or confusion that they may still have regarding learning objective assignments.
#
# > Communication is a fundamental skill underlying statistics and data science, so STA130 Homework based on ChatBots helps practice effective two-way communication as part of a "realistic" dialogue activity supporting underlying conceptual understanding building.
#
# It will likely become increasingly tempting to rely on ChatBots to "do the work for you". But when you find yourself frustrated with a ChatBots inability to give you the results you're looking for, this is a "hint" that you've become overreliant on the ChatBots. Your objective should not be to have ChatBots "do the work for you", but to use ChatBots to help you build your understanding so you can efficiently leverage ChatBots (and other resources) to help you work more efficiently.<br><br>
#
# </details>
#
# <details class="details-example"><summary style="color:blue"><u>Instructions</u></summary>
#
# ### Instructions
#
# 1. Code and write all your answers (for both the "Pre-lecture" and "Post-lecture" HW) in a python notebook (in code and markdown cells)
#
# > It is *suggested but not mandatory* that you complete the "Pre-lecture" HW prior to the Monday LEC since (a) all HW is due at the same time; but, (b) completing some of the HW early will mean better readiness for LEC and less of a "procrastentation cruch" towards the end of the week...
#
# 2. Paste summaries of your ChatBot sessions (including link(s) to chat log histories if you're using ChatGPT) within your notebook
#
# > Create summaries of your ChatBot sessions by using concluding prompts such as "Please provide a summary of our exchanges here so I can submit them as a record of our interactions as part of a homework assignment" or, "Please provide me with the final working verson of the code that we created together"
#
# 3. Save your python jupyter notebook in your own account and "repo" on [github.com](github.com) and submit a link to that notebook though Quercus for assignment marking<br><br>
#
# </details>
#
# <details class="details-example"><summary style="color:blue"><u>Prompt Engineering?</u></summary>
#
# ### Prompt Engineering?
#
# The questions (as copy-pasted prompts) are designed to initialize appropriate ChatBot conversations which can be explored in the manner of an interactive and dynamic textbook; but, it is nonetheless **strongly recommendated** that your rephrase the questions in a way that you find natural to ensure a clear understanding of the question. Given sensible prompts the represent a question well, the two primary challenges observed to arise from ChatBots are
#
# 1. conversations going beyond the intended scope of the material addressed by the question; and,
# 2. unrecoverable confusion as a result of sequential layers logial inquiry that cannot be resolved.
#
# In the case of the former (1), adding constraints specifying the limits of considerations of interest tends to be helpful; whereas, the latter (2) is often the result of initial prompting that leads to poor developments in navigating the material, which are likely just best resolve by a "hard reset" with a new initial approach to prompting.  Indeed, this is exactly the behavior [hardcoded into copilot](https://answers.microsoft.com/en-us/bing/forum/all/is-this-even-normal/0b6dcab3-7d6c-4373-8efe-d74158af3c00)...
#
# </details>

# %% [markdown]
# ### Marking Rubric (which may award partial credit)
#
# - [0.1 points]: All relevant ChatBot summaries [including link(s) to chat log histories if you're using ChatGPT] are reported within the notebook
# - [0.2 points]: Evaluation of correctness and clarity in written communication for Question "3"
# - [0.2 points]: Evaluation of correctness and clarity in written communication for Question "4"
# - [0.2 points]: Evaluation of submitted work and conclusions for Question "9"
# - [0.3 points]: Evaluation of written communication of the "big picture" differences and correct evidence assessement for Question "11"

# %% [markdown]
# ## "Pre-lecture" versus "Post-lecture" HW?
#
# - _**Your HW submission is due prior to the Nov08 TUT on Friday after you return from Reading Week; however,**_
# - _**this homework assignment is longer since it covers material from both the Oct21 and Nov04 LEC (rather than a single LEC); so,**_
# - _**we'll brake the assignment into "Week of Oct21" and "Week of Nov04" HW and/but ALL of it will be DUE prior to the Nov08 TUT**_

# %% [markdown]
# ## "Week of Oct21" HW [*due prior to the Nov08 TUT*]

# %% [markdown]
# ### 1. Explain the theoretical Simple Linear Regression model in your own words by describing its components (of predictor and outcome variables, slope and intercept coefficients, and an error term) and how they combine to form a sample from normal distribution; then, create *python* code explicitly demonstrating your explanation using *numpy* and *scipy.stats* <br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _Your answer can be quite concise and will likely just address the "mathematical" and "statistical" aspects of the process of a **Simple Linear Model** specification, perhaps giving an intuitive interpretation summary of the result as a whole_
# >
# > - _Your code could be based on values for `n`, `x`, `beta0`, `beta1`, and `sigma`; and, then create the `errors` and `Y`_
# >
# > - _The predictors $x_i$ can be fixed arbitrarily to start the process (perhaps sampled using `stats.uniform`), and they are conceptually different from the creation of **error** (or **noise**) terms $\epsilon_i$ which are sampled from a **normal distribution** (with some aribtrarily *a priori* chosen **standard deviation** `scale` parameter $\sigma$) which are then combined with $x_i$ through the **Simple Linear Model** equation (based on aribtrarily *a priori* chosen **slope** and **intercept coefficients**) to produce the $Y_i$ outcomes_
# >
# > - _It should be fairly easy to visualize the "a + bx" line defined by the **Simple Linear Model** equation, and some **simulated** data points around the line in a `plotly` figure using the help of a ChatBot_
# >
# > _If you use a ChatBot (as expected for this problem), **don't forget to ask for summaries of your ChatBot session(s) and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatGPT)**_
# >
# >
# > _**Question Scope Warning:** Be careful when using a ChatBot to help you with creating an example dataset and coding up a visualization though, **because it might suggest creating (and visualizing) a fitted model for to your data (rather than the theoretical model); but, this is not what this question is asking you to demonstrate**. This question is not asking about how to produce a fitted **Simple Linear Regression** model or explain how model **slope** and **intercept coefficients** are calculated (e.g., using "ordinary least squares" or analytical equations to estimate the **coefficients**  for an observed dataset)._
# >
# > ```python
# > # There are two distinct ways to use `plotly` here
# >
# > import plotly.express as px
# > px.scatter(df, x='x',  y='Y', color='Data',
# >            trendline='ols', title='Y vs. x')
# >
# > import plotly.graph_objects as go
# > fig = go.Figure()
# > fig.add_trace(go.Scatter(x=x, y=Y, mode='markers', name='Data'))
# >
# > # The latter is preferable since `trendline='ols'` in the former
# > # creates a fitted model for the data and adds it to the figure
# > # and, again, THAT IS NOT what this problem is asking for right now
# > ```
# >
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# # Q1.
#
# In a Simple Linear Regression model, we aim to describe the relationship between an outcome variable Y (often called the dependent or response variable) and a predictor variable X (the independent variable). Mathematically, we represent this relationship as:
#
# **Yi​=β0​+β1​X i​+ϵi​**
#
# where:
#
# * 𝛽0 is the intercept, representing the expected value of Y when X=0.
# * 𝛽1 is the slope, indicating the change in Y for a one-unit change in X.
# * 𝜖𝑖 is the error term (or noise), assumed to be independently drawn from a normal distribution with mean 0 and standard deviation σ, capturing the random variations that are not explained by the linear relationship.
#
# The predictors 𝑋𝑖 can be chosen or sampled independently, such as from a uniform distribution, to form a set of fixed values. We generate a sample of Y values that approximate a normal distribution around the regression line.

# %%
import numpy as np
import scipy.stats as stats
import plotly.graph_objs as go

# Parameters
n = 100  # Number of observations
beta0 = 2.0  # Intercept
beta1 = 1.5  # Slope
sigma = 10.0  # Standard deviation of the error term

# Generate predictor variable X from a uniform distribution
X = stats.uniform.rvs(0, 10, size=n)  # X values between 0 and 10

# Generate random error term epsilon from a normal distribution
epsilon = np.random.normal(0, sigma, n)

# Calculate outcome variable Y
Y = beta0 + beta1 * X + epsilon

# Create the regression line without noise
Y_line = beta0 + beta1 * X

# Plot the regression line and the data points
trace_data = go.Scatter(x=X, y=Y, mode='markers', name='Simulated Data Points')
trace_line = go.Scatter(x=X, y=Y_line, mode='lines', name='Regression Line')

layout = go.Layout(
    title='Simple Linear Regression Model Simulation',
    xaxis=dict(title='X (Predictor Variable)'),
    yaxis=dict(title='Y (Outcome Variable)')
)

fig = go.Figure(data=[trace_data, trace_line], layout=layout)
fig.show(renderer="png")

# %% [markdown]
# ### 2. Use a dataset simulated from your theoretical Simple Linear Regression model to demonstrate how to create and visualize a fitted Simple Linear Regression model using *pandas* and *import statsmodels.formula.api as smf*<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > - _Combine the **simulated** `x` and `Y` into a `pandas` data frame object named `df` with the column names "x" and "Y"_
# >
# > - _Replace the inline question comments below with their answers (working with a ChatBot if needed)_
# >
# > ```python
# > import statsmodels.formula.api as smf  # what is this library for?
# > import plotly.express as px  # this is a ploting library
# >
# > # what are the following two steps doing?
# > model_data_specification = smf.ols("Y~x", data=df)
# > fitted_model = model_data_specification.fit()
# >
# > # what do each of the following provide?
# > fitted_model.summary()  # simple explanation?
# > fitted_model.summary().tables[1]  # simple explanation?
# > fitted_model.params  # simple explanation?
# > fitted_model.params.values  # simple explanation?
# > fitted_model.rsquared  # simple explanation?
# >
# > # what two things does this add onto the figure?
# > df['Data'] = 'Data' # hack to add data to legend
# > fig = px.scatter(df, x='x',  y='Y', color='Data',
# >                  trendline='ols', title='Y vs. x')
# >
# > # This is essentially what above `trendline='ols'` does
# > fig.add_scatter(x=df['x'], y=fitted_model.fittedvalues,
# >                 line=dict(color='blue'), name="trendline='ols'")
# >
# > fig.show() # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS
# > ```
# >
# > _The plotting here uses the `plotly.express` form `fig.add_scatter(x=x, y=Y)` rather than the `plotly.graph_objects` form `fig.add_trace(go.Scatter(x=x, y=Y))`. The difference between these two was noted in the "Further Guidance" comments in the previous question; but, the preference for the former in this case is because `px` allows us to access `trendline='ols'` through `px.scatter(df, x='x',  y='Y', trendline='ols')`_
# >
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
#
# </details>

# %% [markdown]
# # Q2.

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import plotly.express as px

# Define parameters for the theoretical model
n = 100         # Number of observations
beta0 = 5       # Intercept
beta1 = 2       # Slope
sigma = 10       # Standard deviation of errors

# Generate predictor variable x and errors
x = np.linspace(0, 10, n)
errors = np.random.normal(0, sigma, n)

# Generate outcome variable Y based on the theoretical model
Y = beta0 + beta1 * x + errors

# Create a DataFrame
df = pd.DataFrame({'x': x, 'Y': Y})

# Fit the Simple Linear Regression model using statsmodels
model_data_specification = smf.ols("Y ~ x", data=df)  # Model specification
fitted_model = model_data_specification.fit()          # Model fitting

# Display the model summary (optional)
print(fitted_model.summary())  # Detailed model summary
print(fitted_model.summary().tables[1])  # Coefficients table only
print(fitted_model.params)  # Estimated parameters (intercept and slope)
print(fitted_model.rsquared)  # R-squared value

# Visualize the data with the fitted model
df['Data'] = 'Data'  # Adds a column to allow data to be color-coded in the legend
fig = px.scatter(df, x='x', y='Y', color='Data', trendline='ols', title='Y vs. x')

# Alternatively, manually add the trendline if desired
fig.add_scatter(x=df['x'], y=fitted_model.fittedvalues,
                line=dict(color='blue'), name="trendline='ols'")

# Show the plot
fig.show(renderer="png")  # For GitHub and MarkUs compatibility
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     24.81
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):           2.71e-06
# Time:                        21:19:06   Log-Likelihood:                -384.46
# No. Observations:                 100   AIC:                             772.9
# Df Residuals:                      98   BIC:                             778.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.6152      2.268      1.594      0.114      -0.885       8.116
# ...

# %% [markdown]
# ### 3. Add the line from Question 1 on the figure of Question 2 and explain the difference between the nature of the two lines in your own words; *but, hint though: simulation of random sampling variation*<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _This question is effectively asking you to explain what the combined code you produced for Questions 1 and 2 is trying to demonstrate overall. If you're working with a ChatBot (as expected), giving these two sets of code as context, and asking what the purpose of comparing these lines could be would be a way to get some help in formulating your answer_
# >
# > _The graphical visualization aspect of this question could be accomplished by appending the following code to the code provided in Question 2._
# >
# > ```python
# > # what does this add onto the figure in constrast to `trendline='ols'`?
# > x_range = np.array([df['x'].min(), df['x'].max()])
# > # beta0 and beta1 are assumed to be defined
# > y_line = beta0 + beta1 * x_range
# > fig.add_scatter(x=x_range, y=y_line, mode='lines',
# >                 name=str(beta0)+' + '+str(beta1)+' * x',
# >                 line=dict(dash='dot', color='orange'))
# >
# > fig.show() # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS
# > ```
# >
# > _The right way to interactively "see" the answer to this question is to repeatedly create different dataset **simulations** using your theoretical model and the corresponding fitted models, and repeatedly visualize the data and the two lines over and over... this would be as easy as rerunning a single cell containing your simulation and visualization code..._
# >
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# # Q3.

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import plotly.graph_objects as go
import plotly.express as px
from scipy.stats import norm

# Set parameters for the model
n = 100  # Number of observations
beta0 = 5  # Intercept
beta1 = 2  # Slope
sigma = 10  # Standard deviation of error terms

# Generate predictor variable x (uniformly distributed)
x = np.linspace(0, 10, n)

# Generate error terms (normally distributed)
errors = norm.rvs(loc=0, scale=sigma, size=n)

# Generate outcome variable Y based on theoretical model
Y = beta0 + beta1 * x + errors

# Create a DataFrame
df = pd.DataFrame({'x': x, 'Y': Y})

# Fit the Simple Linear Regression model using statsmodels
model_data_specification = smf.ols("Y ~ x", data=df)
fitted_model = model_data_specification.fit()

# Create a unified figure
fig = go.Figure()

# Add the simulated data points (Y values with error)
fig.add_trace(go.Scatter(x=x, y=Y, mode='markers', name='Simulated Data'))

# Add the theoretical regression line (without error)
fig.add_trace(go.Scatter(x=x, y=beta0 + beta1 * x, mode='lines', line=dict(color='red', dash='dash'), name='Theoretical Regression Line'))

# Add the fitted regression line from the model
fig.add_trace(go.Scatter(x=df['x'], y=fitted_model.fittedvalues,
                         mode='lines', line=dict(color='blue'), name="Fitted Regression Line"))

# Add layout details
fig.update_layout(title='Comparison of Theoretical and Fitted Simple Linear Regression Models',
                  xaxis_title='Predictor (x)',
                  yaxis_title='Outcome (Y)',
                  legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01))

# Show the plot
fig.show(renderer="png")  # For GitHub and MarkUs compatibility

# %% [markdown]
# # Explanations of differences between two lines
#
# Bascially from observations, here is the main difference from my understanding:
#
# **1. Theoretical Line (Dashed Line): This line represents the exact equation from the theoretical Simple Linear Regression model without any randomness. It is the "true" relationship that we would expect if there were no random error.**
#
# **2. Fitted Regression Line (Solid Line): This line is based on the model fit to the simulated data points, which include random variation from the error term 𝜖. This line is slightly different from the theoretical line because it is influenced by the specific random noise in this particular simulated sample.**
#
# For conclusion, the difference between these lines illustrates sampling variation, which arises because each sample will have slightly different random noise. In practice, this means that with each new dataset (i.e., with different random noise), the fitted line may differ slightly from the theoretical line, reflecting the inherent variability of real-world data. This distinction highlights why fitted models may not exactly match theoretical models in applied settings.
#
# **Also, Experimenting with Repeated Simulations**
#
# Repeatedly running this combined code block—generating a new dataset, fitting a new model, and visualizing the results—demonstrates sampling variation in action. Each time I run it:
#
# 1. The data points will vary due to newly generated random errors.
#
# 2. The fitted line will shift slightly, depending on the specific random errors added in that iteration.
#
# 3. By observing this variability across simulations, you can develop an intuition for how a single fitted model can approximate an underlying relationship but may differ slightly each time due to noise. This interactive approach is particularly useful for grasping the concept of sampling variability and understanding that fitted regression models are estimates that can vary across different samples, even when based on the same theoretical model.

# %% [markdown]
# ### 4. Explain how *fitted_model.fittedvalues* are derived on the basis of *fitted_model.summary().tables[1]* (or more specifically  *fitted_model.params* or *fitted_model.params.values*)<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _The previous questions used code to explore the distinction between theoretical (true) $Y_i = \beta_0 + \beta_1 x_i + \epsilon_i \;[\text{where } \epsilon_i \sim \mathcal{N}(0, \sigma)]\;$ and fitted (estimated) $\hat{y}_i = \hat{\beta}_0 + \hat{\beta}_1 x_i$ **Simple Linear Regression** models_
# >
# > _This question asks you to explicitly illustrate how the the latter "in sample predictions" of the fitted **Simple Linear Regression** model $\hat{y}_i = \hat{\beta}_0 + \hat{\beta}_1 x_i$ are made (in contrast to the linear equation of the theoretical model)_
# >
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# # Q4
#
# **Firstly, the fitted_model.fittedvalues in a Simple Linear Regression model are the predicted values for each observation in the dataset. These predicted values are calculated directly from the estimated coefficients for the intercept and slope, which are stored in fitted_model.params.**
#
# From fomular itself(**Yi​=β0​+β1​X i​+ϵi​**), I have explored a little bit in Q1, however:
#
# **Fitted Model: In practice, we don’t know the true values of β0and β1. Instead, we estimate them from sample data, giving us estimated intercept and estimated slop. Using these estimates, the fitted model for each observation 𝑖 is:** $\hat{y}_i = \hat{\beta}_0 + \hat{\beta}_1 x_i$
#
#
# Here are three steps which can be derived from my basic understanding:
#
# 1. Estimated Coefficients: After fitting the regression model, statsmodels provides the estimated coefficients in fitted_model.params. This object contains:
#
# * fitted_model.params[0] (or fitted_model.params['Intercept']), which is the estimated intercept.
# * fitted_model.params[1] (or fitted_model.params['X']), which is the estimated slope for the predictor variable X.
#
# 2. Prediction Calculation: fitted_model.fittedvalues calculates the predicted values by applying these coefficients to each observation's predictor value X. For each observation in the dataset, it multiplies the predictor value by the estimated slope and adds the estimated intercept.
#
# 3. Summary Table Reference: If I examine fitted_model.summary().tables[1], I'll see these coefficients in the "coef" column, which directly correspond to fitted_model.params. These values are then used to calculate fitted_model.fittedvalues for each observation.
#
# Simply summarize, fitted_model.fittedvalues is derived by applying **the estimated intercept and slope (from fitted_model.params) to each observation’s predictor variable, providing the model's in-sample predictions based on the fitted regression line.**

# %% [markdown]
# ### 5. Explain concisely in your own words what line is chosen for the fitted model based on observed data using the "ordinary least squares" method (as is done by *trendline='ols'* and *smf.ols(...).fit()*) and why it requires "squares"<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _This question addresses the use of **residuals** $\text{e}_i = \hat \epsilon_i = Y_i - \hat y_i$ (in contrast to the **error** terms $\epsilon_i$ of the theoretical model), and particularly, asks for an explanation based on the following visualization_
# >
# > ```python
# > import scipy.stats as stats
# > import numpy as np
# > import pandas as pd
# > import statsmodels.formula.api as smf
# > import plotly.express as px
# >
# > n,x_min,x_range,beta0,beta1,sigma = 20,5,5,2,3,5
# > x = stats.uniform(x_min, x_range).rvs(size=n)
# > errors = stats.norm(loc=0, scale=sigma).rvs(size=n)
# > Y = beta0 + beta1 * x + errors
# >
# > df = pd.DataFrame({'x': x, 'y': Y})
# > model_data_specification = smf.ols("Y~x", data=df)
# > fitted_model = model_data_specification.fit()
# >
# > df['Data'] = 'Data' # hack to add data to legend
# > fig = px.scatter(df, x='x',  y='Y', color='Data',
# >                  trendline='ols', title='Y vs. x')
# >
# > # This is what `trendline='ols'` is
# > fig.add_scatter(x=df['x'], y=fitted_model.fittedvalues,
# >                 line=dict(color='blue'), name="trendline='ols'")
# >
# > x_range = np.array([df['x'].min(), df['x'].max()])
# > y_line = beta0 + beta1 * x_range
# > fig.add_scatter(x=x_range, y=y_line, mode='lines',
# >                 name=str(beta0)+' + '+str(beta1)+' * x',
# >                 line=dict(dash='dot', color='orange'))
# >
# > # Add vertical lines for residuals
# > for i in range(len(df)):
# >     fig.add_scatter(x=[df['x'][i], df['x'][i]],
# >                     y=[fitted_model.fittedvalues[i], df['Y'][i]],
# >                     mode='lines',
# >                     line=dict(color='red', dash='dash'),
# >                     showlegend=False)
# >
# > # Add horizontal line at y-bar
# > fig.add_scatter(x=x_range, y=[df['Y'].mean()]*2, mode='lines',
# >                 line=dict(color='black', dash='dot'), name='y-bar')
# >
# > fig.show() # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS
# > ```
# >
# > _**Question Scope Warning**: we are not looking for any explanation realted to the mathematical equations for the line chosen for the **Simple Linear Regression** model by the "ordinary least squares" method, which happen to be_
# >
# > _$$\hat \beta_1 = r_{xy}\frac{s_y}{s_x} \quad \text{ and } \quad  \hat\beta_0 = \bar {y}-\hat \beta_1\bar {x}$$_
# >
# > _where $r_{xy}$ is the **correlation** between $x$ and $Y$ and $s_x$ and $s_Y$ are the **sample standard deviations** of $x$ and $y$_
# >
# > ---
# >
# > ```python
# > # Use this if you need it
# > # https://stackoverflow.com/questions/52771328/plotly-chart-not-showing-in-jupyter-notebook
# > import plotly.offline as pyo
# > # Set notebook mode to work in offline
# > pyo.init_notebook_mode()
# > ```
# >
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
#
# </details>

# %% [markdown]
# # Q5.
#
# **The line chosen for the fitted model using the Ordinary Least Squares (OLS) method is the one that minimizes the total squared differences between the observed data points and the predicted values on the line. This line is often referred to as the "best-fit" line.**
#
# 1. Preventing Cancellation: Squaring ensures that positive and negative residuals don’t cancel each other out, giving a true measure of total error.
#
# 2. Penalizing Larger Errors: Squaring emphasizes larger errors more, which helps ensure the line is as close as possible to all points.
#
# By minimizing this sum of squared errors, OLS provides the most accurate line through the data based on observed patterns, balancing overall prediction accuracy across all points.

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import plotly.express as px

# Set parameters for simulation
n, x_min, x_range, beta0, beta1, sigma = 20, 5, 5, 2, 3, 5
x = stats.uniform(x_min, x_range).rvs(size=n)
errors = stats.norm(loc=0, scale=sigma).rvs(size=n)
Y = beta0 + beta1 * x + errors

# Create DataFrame
df = pd.DataFrame({'x': x, 'y': Y})

# Fit the model
model_data_specification = smf.ols("y ~ x", data=df) 
fitted_model = model_data_specification.fit() 

# Add a column for color-coding in the plot
df['Data'] = 'Data'  # hack to add data to legend

# Create scatter plot with trendline
fig = px.scatter(df, x='x', y='y', color='Data', 
                 trendline='ols', title='y vs. x')

# Overlay the trendline from statsmodels
fig.add_scatter(x=df['x'], y=fitted_model.fittedvalues,
                line=dict(color='blue'), name="trendline='ols'")

# Define the theoretical line based on beta0 and beta1
x_range = np.array([df['x'].min(), df['x'].max()])
y_line = beta0 + beta1 * x_range
fig.add_scatter(x=x_range, y=y_line, mode='lines',
                name=str(beta0) + ' + ' + str(beta1) + ' * x', 
                line=dict(dash='dot', color='orange'))

# Add vertical lines for residuals
for i in range(len(df)):
    fig.add_scatter(x=[df['x'][i], df['x'][i]],
                    y=[fitted_model.fittedvalues[i], df['y'][i]],
                    mode='lines',
                    line=dict(color='red', dash='dash'),
                    showlegend=False)
    
# Add horizontal line at y-bar
fig.add_scatter(x=x_range, y=[df['y'].mean()] * 2, mode='lines',
                line=dict(color='black', dash='dot'), name='y-bar')

# Show plot
fig.show(renderer="png")

# %% [markdown]
# ### 6. Explain why the first expression below can be interpreted as "the proportion of variation in (outcome) Y explained by the model (i.e. _fitted_model.fittedvalues_)"; and therefore, why _fitted_model.rsquared_ can be interpreted as a measure of the accuracy of the model; and, therefore what the two _np.corrcoef(...)[0,1]\*\*2_ expressions capture in the context of _Simple Linear Regression models_.
#
# 1. `1-((Y-fitted_model.fittedvalues)**2).sum()/((Y-Y.mean())**2).sum()`
# 2. `fitted_model.rsquared`
# 3. `np.corrcoef(Y,fitted_model.fittedvalues)[0,1]**2`
# 4. `np.corrcoef(Y,x)[0,1]**2`<br><br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _**R-squared** is the "the proportion of variation in (outcome) $Y$ explained by the model ($\hat y_i$)" and is defined as_
# >
# > _$R^2 = 1 - \frac{\sum_{i=1}^n(Y_i-\hat y)^2}{\sum_{i=1}^n(Y_i-\bar Y)^2}$_
# >
# > _The visuzation provided in the previous problem can be used to consider $(Y_i-\bar Y)^2$ as the squared distance of the $Y_i$ to their sample average $\bar Y$ as opposed to the squared **residuals** $(Y_i-\hat y)^2$ which is the squared distance of the $Y_i$ to their fitted (predicted) values $Y_i$._
# >
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# # Q6.
#
# Interpretation of the Expressions for R-squared:
#
# 1. The first expression: 1-((Y-fitted_model.fittedvalues)**2).sum()/((Y-Y.mean())**2).sum()
#
# Total Variation in Y:
#
# The denominator in this expression, ((Y - Y.mean())**2).sum(), represents the total variation in Y. This measures how much the values of Y differ from their overall average and captures the overall spread of Y values around their mean.
# Unexplained Variation (Residual Sum of Squares):
#
# 2. The numerator, ((Y - fitted_model.fittedvalues)**2).sum(),
#
# calculates the unexplained variation, or residual sum of squares. This is the sum of the squared differences between the actual Y values and the model’s predicted values, fitted_model.fittedvalues. This residual variation measures how far off the model's predictions are from the observed values of Y.
# Proportion of Variation Explained:
#
# Subtracting the ratio of unexplained variation from 1 gives us the proportion of the total variation in Y that is explained by the model. This value is called R-squared. It shows how well the model captures the variability in the data: a higher R-squared value means the model explains more of the variation in Y.
# Therefore, fitted_model.rsquared in statsmodels directly provides this proportion of variation in Y that the model explains. This value serves as a measure of the model’s accuracy: the closer R-squared is to 1, the more accurately the model captures the data’s trend.
#
# 3. Interpretation of np.corrcoef(Y, fitted_model.fittedvalues)[0,1]**2
#
# The expression np.corrcoef(Y, fitted_model.fittedvalues)[0,1]**2 calculates the squared correlation between the observed values of Y and the model’s predicted values. This squared correlation has a direct relationship with R-squared in a simple linear regression model, as it also represents the proportion of the variation in Y that is explained by the model. In this context, the squared correlation between Y and the predictions gives us the same R-squared value because:
#
# A high correlation between Y and the predicted values means that the model’s predictions closely follow the pattern of the actual Y values.
# Squaring the correlation coefficient removes negative values and aligns it with the interpretation of R-squared as a proportion.
#
# 4. Interpretation of np.corrcoef(Y, x)[0,1]**2
#
# For np.corrcoef(Y, x)[0,1]**2, this expression captures the squared correlation between Y and the predictor variable, x. This squared correlation measures the proportion of variation in Y directly explained by a simple linear relationship with x, without fitting a full regression model. In other words:
#
# This squared correlation tells us how much of the variation in Y can be explained by just looking at its linear association with x.
# In simple linear regression, this value is equivalent to R-squared because the model only has one predictor. Therefore, the correlation between Y and x (when squared) provides a measure of how much Y varies with x, which is exactly what the model seeks to capture.

# %% [markdown]
# ### 7. Indicate a couple of the assumptions of the *Simple Linear Regression* model specification that do not seem compatible with the example data below<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _Hint: What even ARE the assumptions of the  **Simple Linear Regression** model, you ask? Have a look at the mathematical specification and see if what it seems to be assuming._
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# # Q7.
#
# In the context of Simple Linear Regression, several key assumptions underlie the model’s specification. Here are two assumptions that may not be compatible with the example data you provided:
#
# 1. **Linearity**: Simple Linear Regression assumes that there is a linear relationship between the predictor x and the outcome Y. If a scatter plot of x and Y shows a curved or non-linear pattern, then the linearity assumption is likely violated. This would mean the model may not effectively capture the true relationship between x and Y.
#
# 2. **Homoscedasticity**: The assumption of homoscedasticity requires that the variance of errors (residuals) remains constant across all levels of the predictor variable x. If residuals appear to spread out (increase or decrease) as x increases, this suggests heteroscedasticity, indicating that the error variance is not constant. This can lead to biased estimates of the standard errors, affecting inference.
#
# If these assumptions are violated in the data, it suggests that the Simple Linear Regression model may not be the most appropriate model for the data, and alternative modeling approaches or transformations might be more suitable.

# %%
import pandas as pd
from scipy import stats
import plotly.express as px
from plotly.subplots import make_subplots

# This data shows the relationship between the amount of fertilizer used and crop yield
data = {'Amount of Fertilizer (kg) (x)': [1, 1.2, 1.4, 1.6, 1.8, 2, 2.2, 2.4, 2.6, 
                                          2.8, 3, 3.2, 3.4, 3.6, 3.8, 4, 4.2, 4.4, 
                                          4.6, 4.8, 5, 5.2, 5.4, 5.6, 5.8, 6, 6.2, 
                                          6.4, 6.6, 6.8, 7, 7.2, 7.4, 7.6, 7.8, 8, 
                                          8.2, 8.4, 8.6, 8.8,9, 9.2, 9.4, 9.6],
        'Crop Yield (tons) (Y)': [18.7, 16.9, 16.1, 13.4, 48.4, 51.9, 31.8, 51.3, 
                                  63.9, 50.6, 58.7, 82.4, 66.7, 81.2, 96.5, 112.2, 
                                  132.5, 119.8, 127.7, 136.3, 148.5, 169.4, 177.9, 
                                  186.7, 198.1, 215.7, 230.7, 250.4, 258. , 267.8, 
                                  320.4, 302. , 307.2, 331.5, 375.3, 403.4, 393.5,
                                  434.9, 431.9, 451.1, 491.2, 546.8, 546.4, 558.9]}
df = pd.DataFrame(data)
fig1 = px.scatter(df, x='Amount of Fertilizer (kg) (x)', y='Crop Yield (tons) (Y)',
                  trendline='ols', title='Crop Yield vs. Amount of Fertilizer')

# Perform linear regression using scipy.stats
slope, intercept, r_value, p_value, std_err = \
    stats.linregress(df['Amount of Fertilizer (kg) (x)'], df['Crop Yield (tons) (Y)'])
# Predict the values and calculate residuals
y_hat = intercept + slope * df['Amount of Fertilizer (kg) (x)']
residuals = df['Crop Yield (tons) (Y)'] - y_hat
df['Residuals'] = residuals
fig2 = px.histogram(df, x='Residuals', nbins=10, title='Histogram of Residuals',
                    labels={'Residuals': 'Residuals'})

fig = make_subplots(rows=1, cols=2,
                    subplot_titles=('Crop Yield vs. Amount of Fertilizer', 
                                    'Histogram of Residuals'))
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)
for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)
fig.update_layout(title='Scatter Plot and Histogram of Residuals',
    xaxis_title='Amount of Fertilizer (kg)', yaxis_title='Crop Yield (tons)',
    xaxis2_title='Residuals', yaxis2_title='Frequency', showlegend=False)

fig.show(renderer="png") # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS

# %% [markdown]
# ## "Week of Nov04" HW [due prior to the Nov08 TUT]
#
# _**In place of the "Data Analysis Assignment" format we introduced for the previous weeks' HW, the remaining questions will be a collection of exercises based around the following data**_
#
# > The details of the "LOWESS Trendline" shown below are not a part of the intended scope of the activities here, but it is included since it is suggestive of the questions we will consider and address here

# %%
import plotly.express as px
import seaborn as sns
import statsmodels.api as sm

# The "Classic" Old Faithful Geyser dataset: ask a ChatBot for more details if desired
old_faithful = sns.load_dataset('geyser')

# Create a scatter plot with a Simple Linear Regression trendline
fig = px.scatter(old_faithful, x='waiting', y='duration', 
                 title="Old Faithful Geyser Eruptions", 
                 trendline='ols')#'lowess'

# Add a smoothed LOWESS Trendline to the scatter plot
lowess = sm.nonparametric.lowess  # Adjust 'frac' to change "smoothness bandwidth"
smoothed = lowess(old_faithful['duration'], old_faithful['waiting'], frac=0.25)  
smoothed_df = pd.DataFrame(smoothed, columns=['waiting', 'smoothed_duration'])
fig.add_scatter(x=smoothed_df['waiting'], y=smoothed_df['smoothed_duration'], 
                mode='lines', name='LOWESS Trendline')

fig.show(renderer="png") # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS

# %% [markdown]
# ### 8. Specify a *null hypothesis* of "no linear association (on average)" in terms of the relevant *parameter* of the *Simple Linear Regression* model, and use the code below to characterize the evidence in the data relative to the *null hypothesis* and interpret your subsequent beliefs regarding the Old Faithful Geyser dataset.<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _Remember that **Hypothesis Testing** is not a "mathematical proof"_
# >
# > - _We do not prove $H_0$ false, we instead give evidence against the $H_0$: "We reject the null hypothesis with a p-value of XYZ, meaning we have ABC evidence against the null hypothesis"_
# > - _We do not prove $H_0$ is true, we instead do not have evidence to reject $H_0$: "We fail to reject the null hypothesis with a p-value of XYZ"_
#
# |p-value|Evidence|
# |-|-|
# |$$p > 0.1$$|No evidence against the null hypothesis|
# |$$0.1 \ge p > 0.05$$|Weak evidence against the null hypothesis|
# |$$0.05 \ge p > 0.01$$|Moderate evidence against the null hypothesis|
# |$$0.01 \ge p > 0.001$$|Strong evidence against the null hypothesis|
# |$$0.001 \ge p$$|Very strong evidence against the null hypothesis|
#
# </details>
#
# > ```python
# > import seaborn as sns
# > import statsmodels.formula.api as smf
# >
# > # The "Classic" Old Faithful Geyser dataset
# > old_faithful = sns.load_dataset('geyser')
# >
# > linear_for_specification = 'duration ~ waiting'
# > model = smf.ols(linear_for_specification, data=old_faithful)
# > fitted_model = model.fit()
# > fitted_model.summary()
# > ```

# %% [markdown]
# # Q8.
#
# In the context of Simple Linear Regression, the null hypothesis of "no linear association (on average)" between the variables waiting (predictor) and duration (outcome) can be stated as:
#
# **Null Hypothesis (H0): The slope parameter, beta1, is equal to zero. This means that there is no linear association between waiting and duration on average.**
#
# * In terms of parameters: H0: beta1 = 0
# * Alternative Hypothesis (H1): There is a linear association, so the slope is not zero (H1: beta1 ≠ 0).
#
# **Using the Code to Characterize Evidence Against the Null Hypothesis**
#
# The code provided loads the Old Faithful Geyser dataset, specifies a Simple Linear Regression model with duration as the outcome and waiting as the predictor, and then fits the model. Running fitted_model.summary() will output a table with the regression results, including the estimated slope and intercept, p-values, R-squared, and other key statistics.
#
# Here’s a breakdown of how we interpret this summary to assess the null hypothesis:
#
# 1. Slope Estimate and p-value:
#
# In the summary, look for the row labeled waiting (the predictor variable). This row shows the estimated slope and its p-value.
# If the p-value for the waiting coefficient is less than a significance threshold (commonly 0.05), we reject the null hypothesis. This would suggest evidence of a statistically significant linear relationship between waiting and duration.
#
# 2. R-squared:
#
# R-squared indicates the proportion of variance in duration that is explained by waiting. A higher R-squared value supports the idea that waiting has a meaningful association with duration.
# Confidence Interval:
#
# The summary also includes a confidence interval for the slope estimate. If this interval does not contain zero, it provides further evidence against the null hypothesis.
#
# **Interpretation of the Evidence in the Old Faithful Dataset**
#
# Based on the summary output:
#
# If the p-value for waiting is very small (say, less than 0.05), this suggests strong evidence against the null hypothesis, indicating that waiting has a statistically significant linear association with duration.
# A high R-squared value would support that waiting explains a substantial amount of variation in duration, making waiting a relevant predictor.
#
# Thus, if the data shows a statistically significant linear relationship, we would conclude that the waiting time between eruptions is indeed associated with the duration of the eruptions. This finding would suggest that the Old Faithful Geyser's behavior can be partially explained by this linear association, and our belief in a meaningful relationship between waiting and duration would increase.

# %%
import seaborn as sns
import statsmodels.formula.api as smf

# The "Classic" Old Faithful Geyser dataset
old_faithful = sns.load_dataset('geyser')

linear_for_specification = 'duration ~ waiting'
model = smf.ols(linear_for_specification, data=old_faithful)
fitted_model = model.fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               duration   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     1162.
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):          8.13e-100
# Time:                        21:19:08   Log-Likelihood:                -194.51
# No. Observations:                 272   AIC:                             393.0
# Df Residuals:                     270   BIC:                             400.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8740      0.160    -11.702      0.000      -2.189      -1.559
# ...

# %% [markdown]
# ### 9. As seen in the introductory figure above, if the delay of the geyser eruption since the previous geyser eruption exceeds approximately 63 minutes, there is a notable increase in the duration of the geyser eruption itself. In the figure below we therefore restrict the dataset to only short wait times. Within the context of only short wait times, is there evidence in the data for a relationship between duration and wait time in the same manner as in the full data set? Using the following code, characterize the evidence against the *null hypothesis* in the context of short wait times which are less than  *short_wait_limit* values of *62*, *64*, *66*.<br>

# %% [markdown]
# # Q9. Generally
#
# To investigate whether a relationship exists between duration and waiting times when restricted to only shorter wait times (less than the specified limits of 62, 64, or 66 minutes), we can examine the output from the regression summary and look at key statistics, specifically the slope, p-value, and R-squared.
#
# **Steps to Characterize Evidence Against the Null Hypothesis for Each short_wait_limit**
#
# 1. Run the Regression: For each short_wait_limit (62, 64, and 66), the code filters the Old Faithful Geyser dataset to include only data where waiting time is below the given limit. It then fits a linear regression model to see if there is still a relationship between waiting and duration in this restricted data.
#
# 2. Examine the Slope (waiting coefficient): The waiting coefficient in the regression output represents the estimated change in duration for each additional minute of waiting. Under the null hypothesis, this slope would be zero, indicating no relationship between waiting and duration.
#
# 3. Evaluate the p-value of the Slope: The p-value associated with the waiting coefficient tells us whether the observed slope is statistically significant. A p-value less than 0.05 would provide evidence against the null hypothesis, suggesting a statistically significant relationship between waiting and duration even within short wait times.
#
# 4. Interpret R-squared: R-squared provides the proportion of the variability in duration that is explained by waiting. A low R-squared would imply that even if the relationship is statistically significant, it does not explain much of the variability in duration within this subset of short wait times.

# %% [markdown]
# # Q9. short_wait_limit = 62

# %%
import plotly.express as px
import statsmodels.formula.api as smf


short_wait_limit = 62
short_wait = old_faithful.waiting < short_wait_limit

print(smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit().summary().tables[1])

# Create a scatter plot with a linear regression trendline
fig = px.scatter(old_faithful[short_wait], x='waiting', y='duration', 
                 title="Old Faithful Geyser Eruptions for short wait times (<"+str(short_wait_limit)+")", 
                 trendline='ols')

fig.show(renderer="png")
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6401      0.309      5.306      0.000       1.025       2.255
# waiting        0.0069      0.006      1.188      0.238      -0.005       0.019
# ...

# %% [markdown]
# **Evidence: When short_wait_limit = 62**
# * Intercept: The estimated intercept is 1.6401 with a p-value of 0.000, which is statistically significant. This represents the expected eruption duration when the waiting time is zero, but in this context, it’s mainly a part of the regression equation rather than a meaningful standalone value.
#
# * Waiting Coefficient (Slope): The coefficient for waiting is 0.0069, with a p-value of 0.238. This p-value is above the typical significance level of 0.05, indicating that there is no statistically significant evidence of a relationship between waiting time and eruption duration for short wait times under 62 minutes.
#
# * Confidence Interval: The confidence interval for the waiting coefficient ranges from -0.005 to 0.019, crossing zero. This further suggests that the relationship is not statistically significant within this subset.
#
#
# **Conclusion**
# For short wait times under 62 minutes: There is insufficient evidence against the null hypothesis that waiting time has no effect on eruption duration. The p-value (0.238) and confidence interval (-0.005 to 0.019) both suggest that any observed relationship could be due to random variation rather than a meaningful effect.

# %% [markdown]
# # Q9. short_wait_limit = 64

# %%
import plotly.express as px
import statsmodels.formula.api as smf


short_wait_limit = 64
short_wait = old_faithful.waiting < short_wait_limit

print(smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit().summary().tables[1])

# Create a scatter plot with a linear regression trendline
fig = px.scatter(old_faithful[short_wait], x='waiting', y='duration', 
                 title="Old Faithful Geyser Eruptions for short wait times (<"+str(short_wait_limit)+")", 
                 trendline='ols')

fig.show(renderer="png")
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4140      0.288      4.915      0.000       0.842       1.986
# waiting        0.0114      0.005      2.127      0.036       0.001       0.022
# ...

# %% [markdown]
# **Evidence: When short_wait_limit = 64**
# * Intercept: The estimated intercept is 1.4140 with a p-value of 0.000, which is statistically significant. This represents the expected eruption duration when the waiting time is zero, though it's more meaningful as part of the regression equation in this context.
#
# * Waiting Coefficient (Slope): The coefficient for waiting is 0.0114 with a p-value of 0.036. This p-value is below the typical significance level of 0.05, indicating that there is statistically significant evidence of a relationship between waiting time and eruption duration for short wait times under 64 minutes.
#
# * Confidence Interval: The confidence interval for the waiting coefficient ranges from 0.001 to 0.022, which does not include zero. This further supports the significance of the relationship, suggesting that as wait time increases, eruption duration tends to increase as well within this restricted subset.
#
# **Conclusion**
# For short wait times under 64 minutes: There is significant evidence against the null hypothesis that waiting time has no effect on eruption duration, as indicated by the p-value of 0.036. The positive slope (0.0114) and the confidence interval that does not contain zero (0.001 to 0.022) suggest a modest positive relationship between waiting time and eruption duration.

# %% [markdown]
# # Q9. short_wait_limit = 66

# %%
import plotly.express as px
import statsmodels.formula.api as smf


short_wait_limit = 66
short_wait = old_faithful.waiting < short_wait_limit

print(smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit().summary().tables[1])

# Create a scatter plot with a linear regression trendline
fig = px.scatter(old_faithful[short_wait], x='waiting', y='duration', 
                 title="Old Faithful Geyser Eruptions for short wait times (<"+str(short_wait_limit)+")", 
                 trendline='ols')

fig.show(renderer="png")
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8619      0.327      2.637      0.010       0.213       1.511
# waiting        0.0221      0.006      3.704      0.000       0.010       0.034
# ...

# %% [markdown]
# **Evidence: When short_wait_limit = 66**
# * Intercept: The estimated intercept is 0.8619 with a p-value of 0.010, which is statistically significant. This represents the expected eruption duration when the waiting time is zero, but it's more meaningful here as part of the regression equation.
#
# * Waiting Coefficient (Slope): The coefficient for waiting is 0.0221 with a p-value of 0.000. This p-value is well below the typical significance level of 0.05, indicating strong statistical evidence against the null hypothesis of no relationship between waiting time and eruption duration for short wait times under 66 minutes.
#
# * Confidence Interval: The confidence interval for the waiting coefficient ranges from 0.010 to 0.034, which does not include zero. This further supports the significance of the relationship, suggesting that as wait time increases, eruption duration also tends to increase within this subset.
#
# **Conclusion**
# For short wait times under 66 minutes: There is strong evidence against the null hypothesis that waiting time has no effect on eruption duration, as indicated by the very low p-value (0.000). The positive slope (0.0221) and the confidence interval that does not contain zero (0.010 to 0.034) indicate a clear positive relationship between waiting time and eruption duration.

# %% [markdown]
# In conclusin, by observing the p-value and R-squared for each limit, we can assess whether there is sufficient evidence to suggest a relationship between waiting and duration within short wait times. **Generally, a low R-squared in this restricted data suggests that the relationship is much weaker compared to the full dataset.** This would imply that the stronger relationship seen in the full dataset is likely driven by the longer wait times, where the increase in waiting time more notably affects eruption duration.

# %% [markdown]
# ### 10. Let's now consider just the (*n=160*) long wait times (as specified in the code below), and write code to do the following:
#
# 1. create fitted **Simple Linear Regression** models for **boostrap samples** and collect and visualize the **bootstrapped sampling distribution** of the **fitted slope coefficients** of the fitted models;
#
#
# 2. **simulate** samples (of size `n=160`) from a **Simple Linear Regression** model that uses $\beta_0 = 1.65$, $\beta_1 = 0$, $\sigma = 0.37$ along with the values of `waiting` for $x$ to create **simuations** of $Y$ and use these collect and visualize the **sampling distribution** of the **fitted slope coefficient** under a **null hypothesis** assumption of "no linear association (on average)"; then,
#
#
# 3. report if $0$ is contained within a 95\% **bootstrapped confidence interval**; and if the **simulated p-value** matches `smf.ols('duration ~ waiting', data=old_faithful[long_wait]).fit().summary().tables[1]`?<br><br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _You'll need to create `for` loops to repeatedly create fitted **Simple Linear Regression** models using different samples, collecting the **fitted slope coeffient** created in each `for` loop "step" in order to visualize the **simulated sampling distributions**_
# >
# > - _A **bootstrapped sample** of the "long wait times" dataset can be created with `old_faithful[long_wait].sample(n=long_wait.sum(), replace=True)`_
# >
# >
# > - _A **simulated** version of the "long wait times under a null hypothesis assumption of **no linear association (on average)**" dataset can be created by first creating `old_faithful_simulation = old_faithful[long_wait].copy()` and then assigning the **simulated** it values with `old_faithful_simulation['duration'] = 1.65 + 0*old_faithful_simulation.waiting + stats.norm(loc=0, scale=0.37).rvs(size=long_wait.sum())`_
# >
# >  _The values $\beta_0 = 1.65$ and $\sigma = 0.37$ are chosen to match what is actually observed in the data, while $\beta_1 = 0$ is chosen to reflect a **null hypothesis** assumption of "no linear assocaition (on average)"; and, make sure that you understand why it is that_
# >
# >
# > - _if `bootstrapped_slope_coefficients` is the `np.array` of your **bootstrapped slope coefficients** then `np.quantile(bootstrapped_slope_coefficients, [0.025, 0.975])` is a 95\% **bootstrapped confidence interval**_
# >
# >
# > - _if `simulated_slope_coefficients` is the `np.array` of your **fitted slope coefficients** **simulated** under a **null hypothesis** "no linear association (on average)" then `(np.abs(simulated_slope_coefficients) >= smf.ols('duration ~ waiting', data=old_faithful[long_wait]).fit().params[1]).mean()` is the **p-value** for the **simulated** **simulated sampling distribution of the slope coeficients** under a **null hypothesis** "no linear association (on average)"_
#
# </details>
# <br>

# %% [markdown]
# # Q10.

# %%
import plotly.express as px

long_wait_limit = 71
long_wait = old_faithful.waiting > long_wait_limit

print(smf.ols('duration ~ waiting', data=old_faithful[long_wait]).fit().summary().tables[1])

# Create a scatter plot with a linear regression trendline
fig = px.scatter(old_faithful[long_wait], x='waiting', y='duration', 
                 title="Old Faithful Geyser Eruptions for short wait times (>"+str(long_wait_limit)+")", 
                 trendline='ols')
fig.show(renderer="png") # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3520      0.476      7.049      0.000       2.413       4.291
# waiting        0.0122      0.006      2.091      0.038       0.001       0.024
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import plotly.express as px
import seaborn as sns

# Load the Old Faithful dataset
old_faithful = sns.load_dataset('geyser')

# Define long wait times condition
long_wait_limit = 71
long_wait = old_faithful.waiting > long_wait_limit
long_wait_data = old_faithful[long_wait]

# Original model for long wait times
original_model = smf.ols('duration ~ waiting', data=long_wait_data).fit()
print(original_model.summary().tables[1])

# Visualize original data with trendline
fig = px.scatter(long_wait_data, x='waiting', y='duration',
                 title="Old Faithful Geyser Eruptions for long wait times (>" + str(long_wait_limit) + ")",
                 trendline='ols')
fig.show(renderer="png")

# Step 1: Bootstrap sampling distribution of slope coefficients
n_bootstraps = 1000
bootstrap_slopes = []

for _ in range(n_bootstraps):
    # Resample with replacement
    bootstrap_sample = long_wait_data.sample(n=160, replace=True)
    # Fit model and record slope
    bootstrap_model = smf.ols('duration ~ waiting', data=bootstrap_sample).fit()
    bootstrap_slopes.append(bootstrap_model.params['waiting'])

# Visualize the bootstrap sampling distribution of the slope coefficients
fig = px.histogram(bootstrap_slopes, nbins=30, title="Bootstrap Sampling Distribution of Slope Coefficients")
fig.update_layout(xaxis_title="Slope Coefficient", yaxis_title="Frequency")
fig.show(renderer="png")

# Step 2: Simulate sampling distribution under null hypothesis
np.random.seed(0)
n_simulations = 1000
null_slope_simulations = []

# Parameters under null hypothesis
beta0 = 1.65
beta1 = 0  # No association
sigma = 0.37

for _ in range(n_simulations):
    # Generate Y using the null hypothesis parameters
    Y_null = beta0 + beta1 * long_wait_data['waiting'] + np.random.normal(0, sigma, size=len(long_wait_data))
    simulated_data = pd.DataFrame({'waiting': long_wait_data['waiting'], 'duration': Y_null})
    # Fit model and record slope
    null_model = smf.ols('duration ~ waiting', data=simulated_data).fit()
    null_slope_simulations.append(null_model.params['waiting'])

# Visualize the null hypothesis sampling distribution of the slope coefficients
fig = px.histogram(null_slope_simulations, nbins=30,
                   title="Sampling Distribution of Slope Coefficients Under Null Hypothesis")
fig.update_layout(xaxis_title="Slope Coefficient", yaxis_title="Frequency")
fig.show(renderer="png")

# Step 3: Check if 0 is within the 95% confidence interval of the bootstrap distribution
bootstrap_ci_lower = np.percentile(bootstrap_slopes, 2.5)
bootstrap_ci_upper = np.percentile(bootstrap_slopes, 97.5)
print(f"95% Bootstrap Confidence Interval for Slope: ({bootstrap_ci_lower}, {bootstrap_ci_upper})")

# Check if 0 is in the bootstrap CI and compare with p-value
if bootstrap_ci_lower <= 0 <= bootstrap_ci_upper:
    print("0 is within the 95% bootstrap confidence interval for the slope.")
else:
    print("0 is NOT within the 95% bootstrap confidence interval for the slope.")

# Compare with original p-value
original_p_value = original_model.pvalues['waiting']
print(f"Original model p-value for the slope: {original_p_value}")
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3520      0.476      7.049      0.000       2.413       4.291
# waiting        0.0122      0.006      2.091      0.038       0.001       0.024
# ...
# 95% Bootstrap Confidence Interval for Slope: (0.0002706135457205156, 0.022456892916018358)
# 0 is NOT within the 95% bootstrap confidence interval for the slope.
# Original model p-value for the slope: 0.038135755338567744

# %% [markdown]
# **Bootstrap Sampling Distribution:**
#
# This part uses resampling with replacement from the long wait time data to generate 1000 bootstrap samples. For each bootstrap sample, a Simple Linear Regression model is fitted, and the slope coefficient is recorded.
# The resulting distribution of slopes helps estimate the uncertainty around the slope from the original model, and we can use it to construct a 95% confidence interval.
#
# **Simulated Sampling Distribution under Null Hypothesis:**
#
# 1. We simulate data assuming no relationship between waiting and duration by setting the slope (beta1) to 0.
# This allows us to observe what the distribution of slope estimates would look like under the null hypothesis, providing a reference for comparison.
# Comparison:
#
# 2. We check if 0 is within the 95% confidence interval of the bootstrap slope coefficients. If it is not, this suggests that there is a statistically significant association between waiting and duration in the long wait data.
# Finally, we compare this to the original model’s p-value for the waiting coefficient. A small p-value (typically less than 0.05) would indicate evidence against the null hypothesis, supporting the conclusion drawn from the bootstrap interval.
#
# 3. By examining both the bootstrap confidence interval and the simulated distribution under the null hypothesis, we gain insight into the robustness of the observed association between waiting time and duration for long waits in the Old Faithful dataset.

# %% [markdown]
# ### 11. Since we've considered wait times of around <64  "short" and wait times of >71 "long", let's instead just divide the data and insead call wait times of <68 "short" and otherwise just call them "long". Consider the *Simple Linear Regression* model specification using an *indicator variable* of the wait time length<br>
#
# $$\large Y_i = \beta_{\text{intercept}} + 1_{[\text{"long"}]}(\text{k_i})\beta_{\text{contrast}} + \epsilon_i \quad \text{ where } \quad \epsilon_i \sim \mathcal N\left(0, \sigma\right)$$
#
# ### where we use $k_i$ (rather than $x_i$) (to refer to the "kind" or "katagory" or "kontrast") column (that you may have noticed was already a part) of the original dataset; and, explain the "big picture" differences between this model specification and the previously considered model specifications<br>
#
# 1. `smf.ols('duration ~ waiting', data=old_faithful)`
# 2. `smf.ols('duration ~ waiting', data=old_faithful[short_wait])`
# 3. `smf.ols('duration ~ waiting', data=old_faithful[long_wait])`
#
# ### and report the evidence against a *null hypothesis* of "no difference between groups "on average") for the new *indicator variable* based model<br>

# %% [markdown]
# # Q11.

# %%
from IPython.display import display

display(smf.ols('duration ~ C(kind, Treatment(reference="short"))', data=old_faithful).fit().summary().tables[1])

fig = px.box(old_faithful, x='kind', y='duration', 
             title='duration ~ kind',
             category_orders={'kind': ['short', 'long']})
fig.show(renderer="png")
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# **A. Differences from Previous Model Specifications**
#
# Here are my three observations:
#
# 1. Direct Comparison of Groups:
#
# Unlike previous models, which examined the relationship between waiting and duration as a continuous predictor, this model directly compares two distinct groups ("short" and "long" waits).**Here, we only assess the average duration difference between the groups rather than modeling the continuous relationship between waiting time and duration.**
#
# 2. Indicator Variable for "kind":
#
# The new model uses a categorical (or indicator) variable for kind rather than treating waiting as a continuous predictor. This simplifies the analysis to a binary comparison.**This change reduces the complexity of interpreting continuous slopes but provides a clear comparison of mean durations across "short" and "long" groups.**
#
# 3. Interpretation of beta_contrast:
#
# **beta_contrast now indicates the average difference in eruption duration between "short" and "long" waits.** In contrast, previous models focused on the slope of waiting, showing how duration changes per unit increase in waiting.
#
# **B. Differences from this pecifications**
#
# 1. Continuous vs. Categorical Treatment of Wait Time
# Full Dataset Model (duration ~ waiting): Treats waiting as a continuous predictor across all wait times, aiming to capture an overall trend in the relationship between wait time and eruption duration. This model assumes that the relationship between wait time and duration is consistent across the entire dataset.
#
# Short Wait Times Model (duration ~ waiting with short wait subset): Focuses on a continuous relationship but only within short wait times. By isolating shorter intervals, this model can reveal unique trends in eruption behavior specific to shorter waits that might not appear in the full dataset.
#
# Long Wait Times Model (duration ~ waiting with long wait subset): Similar to the short wait model but restricted to longer wait times. This model provides insights into how longer waits might uniquely affect eruption duration, which could differ from both short wait behavior and the general trend.
#
# Indicator Variable Model (duration ~ C(kind, Treatment(reference="short"))): Unlike the others, this model treats waiting as a categorical variable, dividing it into "short" and "long" wait times. It does not examine a continuous change in duration as wait time increases but rather compares the average duration between two distinct groups.
#
# 2. Interpretation of Results
#
# **Full, Short, and Long Wait Models (Continuous):**
#
# These models provide slope estimates for the relationship between wait time and duration within each data subset.
# A positive slope in these models would suggest that as the waiting time increases, so does the eruption duration, but the strength and pattern of this relationship might vary depending on the subset.
# These models allow for granular insights into how eruption duration responds to incremental increases in wait time in different contexts.
#
# **Indicator Variable Model (Categorical):**
#
# This model provides a single measure of difference in average duration between "short" and "long" waits (beta_contrast), which is easier to interpret.It gives a binary comparison rather than showing a per-minute change, allowing for a clear, big-picture view of whether longer waits are associated with significantly different average eruption durations than shorter waits.This model simplifies interpretation by focusing on categorical differences, rather than requiring a continuous interpretation.
#
# 3. Insights on Geyser Behavior
#
# **Continuous Models (Full, Short, and Long Wait):**
#
# * These models explore how the duration responds to minute-by-minute changes in wait time.
# * They help us understand incremental changes in geyser behavior that may depend on whether the wait time is short or long.
# * These models might reveal nonlinearities or specific ranges where the effect of wait time on duration strengthens or weakens.
#
# **Indicator Model (Categorical):**
#
# This model provides a big-picture summary: does the geyser behave differently, on average, after a long wait compared to a short wait? It highlights whether there is a significant overall difference in eruption behavior between short and long waits without getting into minute-by-minute changes. This model may be preferred for a simplified decision or overview, offering an "on-average" comparison that’s useful for broader conclusions.
#
#
# **C. Testing the Null Hypothesis**
#
# In this model, the null hypothesis is that there is no difference in average duration between "short" and "long" wait times. Mathematically, this translates to: Null Hypothesis (H0): beta_contrast = 0 (no difference in mean duration between "short" and "long" waits) Alternative Hypothesis (H1): beta_contrast ≠ 0 (a difference in mean duration exists between the two groups)
#
# **Coefficient for C(kind, Treatment(reference="short"))[T.long]:**
#
# This coefficient represents beta_contrast, the estimated difference in mean duration between "long" and "short" wait times. **This coefficient is statistically significant (p-value < 0.05), it suggests evidence against the null hypothesis, indicating that there is a significant difference in average duration between the two wait time groups.**
#
# Visualization: **The box plot** shows the distribution of duration for both "short" and "long" wait times, allowing us to visually assess whether the durations differ between these groups.

# %% [markdown]
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# ### 12. Identify which of the histograms suggests the plausibility of the assumption that the distribution of *error* terms is normal for each of the models, and explain why the other three do not support this assumption.
#
# > Hint: Question 5 of the *Communication Activity #2* of the Oct25 TUT (addressing an *omitted* section of the TUT) discusses how the assumption in *Simple Linear Regression* that the *error* terms $\epsilon_i \sim \mathcal N\left(0, \sigma\right)$ is diagnostically assessed by evaluating distributional shape of the *residuals* $\text{e}_i = \hat \epsilon_i = Y_i - \hat y_i$

# %% [markdown]
# # Q12.

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from scipy import stats
import numpy as np

model_residuals = {
    '<br>Model 1:<br>All Data using slope': smf.ols('duration ~ waiting', data=old_faithful).fit().resid,
    '<br>Model 2:<br>Short Wait Data': smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit().resid,
    '<br>Model 3:<br>Long Wait Data': smf.ols('duration ~ waiting', data=old_faithful[long_wait]).fit().resid,
    '<br>Model 4:<br>All Data using indicator': smf.ols('duration ~ C(kind, Treatment(reference="short"))', data=old_faithful).fit().resid
}

fig = make_subplots(rows=2, cols=2, subplot_titles=list(model_residuals.keys()))
for i, (title, resid) in enumerate(model_residuals.items()):

    if i == 1:  # Apply different bins only to the second histogram (index 1)
        bin_size = dict(start=-1.9, end=1.9, size=0.2)
    else:
        bin_size = dict(start=-1.95, end=1.95, size=0.3)

    fig.add_trace(go.Histogram(x=resid, name=title, xbins=bin_size, histnorm='probability density'), 
                  row=int(i/2)+1, col=(i%2)+1)
    fig.update_xaxes(title_text="n="+str(len(resid)), row=int(i/2)+1, col=(i%2)+1)    
    
    normal_range = np.arange(-3*resid.std(),3*resid.std(),0.01)
    fig.add_trace(go.Scatter(x=normal_range, mode='lines', opacity=0.5,
                             y=stats.norm(loc=0, scale=resid.std()).pdf(normal_range),
                             line=dict(color='black', dash='dot', width=2),
                             name='Normal Distribution<br>(99.7% of its area)'), 
                  row=int(i/2)+1, col=(i%2)+1)
    
fig.update_layout(title_text='Histograms of Residuals from Different Models')
fig.update_xaxes(range=[-2,2])
fig.show(renderer="png")

# %% [markdown]
# **Model 1 is most likely to support the normality assumption for the residuals, while Models 2, 3, and 4 may exhibit patterns that suggest non-normality due to either restricted data subsets or simplified categorization of the predictor variable.**
#
# In general:
# Model 1 (All Data with Slope) might support normality best, as it considers the entire range of waiting as a continuous predictor, potentially leading to residuals that follow a more typical bell curve.
# Models 2 and 3 (Short and Long Wait Subsets) may show deviations from normality because dividing the data could limit the natural variability of duration and produce uneven or skewed residuals.
# Model 4 (All Data with Indicator) might also show non-normal residuals because it simplifies waiting to a binary variable, which may not capture subtle variations in duration as well as a continuous predictor.

# %% [markdown]
# ### 13. The "short" and "long" wait times are not "before and after" measurements so there are not natural pairs on which to base differences on which to do a "one sample" (paired differences) *hypothesis test*; but, we can do "two sample" hypothesis testing using a *permuation test*, or create a 95% *bootstrap confidence interval* for the difference in means of the two populations.
#
# ### (A) Do a permuation test $\;H_0: \mu_{\text{short}}=\mu_{\text{long}} \; \text{ no difference in duration between short and long groups}$ by "shuffling" the labels
# ### (B) Create a 95% bootstrap confidence interval  by repeatedly bootstrapping within each group and applying *np.quantile(bootstrapped_mean_differences, [0.025, 0.975])* to the collection of differences between the sample means.
# ### (a) Explain how the sampling approaches work for the two simulations.
# ### (b) Compare and contrast these two methods with the *indicator variable* based model approach used in Question 11, explaining how they're similar and different.<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# > _You'll need to create `for` loops for repeated (shuffling simulation) **permutation** and (subgroup) **bootstrapping**, where_
# >
# > - _"shuffling" for **permutation testing** is done like this `old_faithful.assign(kind_shuffled=old_faithful['kind'].sample(n=len(old_faithful), replace=False).values)#.groupby('kind').size()`; then, the **mean difference statistic** is then calculated using `.groupby('kind_shuffled')['duration'].mean().iloc[::-1].diff().values[1]` (so the **observed statistic** is `old_faithful.groupby('kind')['duration'].mean().iloc[::-1].diff().values[1]`_
# >
# >
# > - _"two sample" **bootstrapping** is done like this `old_faithful.groupby('kind').apply(lambda x: x.sample(n=len(x), replace=True)).reset_index(drop=True)#.groupby('kind').size()`; then, the **bootstrapped mean difference statistic** is then calculated using `.groupby('kind')['duration'].mean().iloc[::-1].diff().values[1]` (like the **observed statistic** except this is applied to the **bootstrapped** resampling of `old_faithful`)_
# > ---
# >
# > _Don't forget to ask for summaries of all your different ChatBot sessions and organize and paste these into your homework notebook (including link(s) to chat log histories if you're using ChatBot) But if you're using the STA130 custom NBLM ChatBot, you'll only be able to ask for summaries, of course!_
# </details>

# %% [markdown]
# # Q13.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from scipy import stats

# Load the Old Faithful dataset
old_faithful = sns.load_dataset('geyser')

# Define "short" and "long" wait times based on threshold
threshold = 68
old_faithful['kind'] = np.where(old_faithful['waiting'] < threshold, 'short', 'long')

# Calculate observed difference in means
mean_duration_short = old_faithful[old_faithful['kind'] == 'short']['duration'].mean()
mean_duration_long = old_faithful[old_faithful['kind'] == 'long']['duration'].mean()
observed_diff = mean_duration_long - mean_duration_short

print(f"Observed difference in means (long - short): {observed_diff}")

# Part (A): Permutation Test
n_permutations = 1000
permuted_diffs = []

for _ in range(n_permutations):
    # Shuffle the 'kind' labels
    shuffled_kind = np.random.permutation(old_faithful['kind'])
    # Calculate mean durations for shuffled groups
    mean_short = old_faithful[shuffled_kind == 'short']['duration'].mean()
    mean_long = old_faithful[shuffled_kind == 'long']['duration'].mean()
    # Store the difference
    permuted_diffs.append(mean_long - mean_short)

# Calculate p-value for the observed difference
p_value_perm = np.mean([abs(diff) >= abs(observed_diff) for diff in permuted_diffs])
print(f"Permutation test p-value: {p_value_perm}")

# Plot the permutation test results
import plotly.express as px
fig_perm = px.histogram(permuted_diffs, nbins=30, title="Permutation Test Distribution of Mean Differences")
fig_perm.add_vline(x=observed_diff, line_dash="dash", line_color="red", annotation_text="Observed Difference")
fig_perm.update_layout(xaxis_title="Mean Difference (Long - Short)", yaxis_title="Frequency")
fig_perm.show(renderer="png")

# Part (B): Bootstrap Confidence Interval
n_bootstraps = 1000
bootstrap_diffs = []

for _ in range(n_bootstraps):
    # Bootstrap samples for each group
    sample_short = old_faithful[old_faithful['kind'] == 'short']['duration'].sample(frac=1, replace=True)
    sample_long = old_faithful[old_faithful['kind'] == 'long']['duration'].sample(frac=1, replace=True)
    # Calculate and store the difference in means
    bootstrap_diffs.append(sample_long.mean() - sample_short.mean())

# Calculate the 95% confidence interval
ci_lower, ci_upper = np.quantile(bootstrap_diffs, [0.025, 0.975])
print(f"95% Bootstrap Confidence Interval for the Difference in Means: ({ci_lower}, {ci_upper})")

# Plot the bootstrap results
fig_bootstrap = px.histogram(bootstrap_diffs, nbins=30, title="Bootstrap Distribution of Mean Differences")
fig_bootstrap.add_vline(x=observed_diff, line_dash="dash", line_color="red", annotation_text="Observed Difference")
fig_bootstrap.update_layout(xaxis_title="Mean Difference (Long - Short)", yaxis_title="Frequency")
fig_bootstrap.show(renderer="png")

# Part (C): Indicator Variable Model
indicator_model = smf.ols('duration ~ C(kind, Treatment(reference="short"))', data=old_faithful).fit()
print("Indicator variable model summary:")
print(indicator_model.summary().tables[1])

# Extract p-value and confidence interval for the indicator variable
p_value_indicator = indicator_model.pvalues['C(kind, Treatment(reference="short"))[T.long]']
ci_indicator = indicator_model.conf_int().loc['C(kind, Treatment(reference="short"))[T.long]']
print(f"Indicator variable model p-value: {p_value_indicator}")
print(f"Indicator variable model 95% Confidence Interval: {ci_indicator}")
# Out:
# Observed difference in means (long - short): 2.2036002325581396
# Permutation test p-value: 0.0
# 95% Bootstrap Confidence Interval for the Difference in Means: (2.1039162267441864, 2.2987925581395348)
# Indicator variable model summary:
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                         2.0943      0.041     50.752      0.000       2.013       2.176
# C(kind, Treatment(reference="short"))[T.long]     2.2036      0.052     42.464      0.000       2.101       2.306
# ...
# Indicator variable model p-value: 1.599856531005988e-121
# Indicator variable model 95% Confidence Interval: 0    2.101433
# 1    2.305768
# Name: C(kind, Treatment(reference="short"))[T.long], dtype: float64

# %% [markdown]
# **(a) Explanation of Sampling Approaches**
#
# Permutation Test: The permutation test assumes that, under the null hypothesis, the group labels "short" and "long" have no actual impact on duration. By randomly reassigning labels across the pooled data, we simulate what the distribution of differences in mean duration would look like if there were truly no difference between groups.
# Bootstrap Confidence Interval: The bootstrap method assumes that each observed group is representative of its population. By resampling within each group, we approximate the sampling distribution of the mean duration difference under the observed data. This approach estimates the range of plausible differences in means based on the observed samples. Both approaches are non-parametric and data-driven, but they use different assumptions and resampling techniques to assess the difference in group means.
#
# **(b) Comparison with the Indicator Variable Model Approach**
#
# The indicator variable model approach (using duration ~ C(kind)) differs in several key ways but shares some conceptual similarities.
#
# **Similarity:**
#
# All three methods aim to assess whether there’s a significant difference in mean duration between the "short" and "long" wait groups.
# Each approach ultimately examines the difference in average eruption duration between groups, either by resampling, shuffling, or using regression.
# Differences:
#
# **Methodology:**
#
# The permutation test and bootstrap approaches involve resampling techniques that directly estimate sampling distributions without making assumptions about normality or relying on a specific statistical model.
# The indicator variable model uses a linear regression framework, estimating the difference between groups based on the fitted slope (contrast) for the indicator variable. This assumes a linear relationship and uses parametric estimation methods.
#
# **Interpretation:**
#
# The permutation test provides a p-value that reflects the likelihood of observing a difference as extreme as the one in the data under the null hypothesis of no difference.
# The bootstrap method yields a confidence interval that shows the range of plausible values for the difference in means. If this interval does not contain zero, it suggests a significant difference.
# The indicator variable model estimates the difference in means and provides a p-value based on the regression coefficient for the indicator variable. This p-value tests the null hypothesis that there is no difference between groups, interpreted similarly to the permutation test p-value.
#
# **Statistical Assumptions:**
#
# The permutation test assumes that any observed difference is due to random label assignment under the null hypothesis.The bootstrap approach assumes that each group’s data distribution represents its population distribution.The indicator model assumes linearity, normally distributed errors, and homoscedasticity, making it more model-dependent than the non-parametric permutation and bootstrap tests.

# %% [markdown]
# ### 14. Have you reviewed the course wiki-textbook and interacted with a ChatBot (or, if that wasn't sufficient, real people in the course piazza discussion board or TA office hours) to help you understand all the material in the tutorial and lecture that you didn't quite follow when you first saw it?<br>
#
# <details class="details-example"><summary style="color:blue"><u>Further Guidance</u></summary>
#
# >  _Here is the link of [wiki-textbook](https://github.com/pointOfive/stat130chat130/wiki) in case it gets lost among all the information you need to keep track of_  : )
# >
# > _Just answering "Yes" or "No" or "Somewhat" or "Mostly" or whatever here is fine as this question isn't a part of the rubric; but, the midterm and final exams may ask questions that are based on the tutorial and lecture materials; and, your own skills will be limited by your familiarity with these materials (which will determine your ability to actually do actual things effectively with these skills... like the course project...)_
# </details>

# %% [markdown]
# YES

# %% [markdown]
# **ChatGPT Link for this homework:** https://chatgpt.com/share/6726b91c-ccdc-800b-bdb5-00be1301eda8
#
# **ChatGPT Summary:**
#
# Over the course of our exploration, we delved into key concepts of Simple Linear Regression and statistical hypothesis testing using both theoretical models and simulated datasets. We began by establishing the fundamentals of Simple Linear Regression, examining how predicted values (fitted_model.fittedvalues) are derived using estimated coefficients (fitted_model.params). We explored assumptions underlying the model, including linearity and homoscedasticity, and discussed how the Ordinary Least Squares (OLS) method minimizes the sum of squared residuals to produce a best-fit line. To further our understanding, we examined the interpretation of R-squared as the proportion of variation in the outcome explained by the model and explored how correlation relates to this measure. We then focused on different statistical methods to test hypotheses about model coefficients, employing both permutation tests and bootstrap confidence intervals to assess differences in means between groups.
#
# Through practical applications with the Old Faithful Geyser dataset, we analyzed how eruption duration depends on waiting time, using regression models, indicator variables, and non-parametric testing methods. We compared continuous and categorical model specifications and assessed residuals to evaluate model assumptions. Finally, we contrasted parametric and non-parametric approaches, each of which offered unique insights and strengths. Altogether, this comprehensive exploration reinforced core statistical principles, provided practical techniques for assessing model assumptions, and demonstrated a variety of approaches for analyzing relationships in data, giving a full picture of the process of building and evaluating regression models.

# %% [markdown]
# ## Recommended Additional Useful Activities [Optional]
#
# The "Ethical Profesionalism Considerations" and "Current Course Project Capability Level" sections below **are not a part of the required homework assignment**; rather, they are regular weekly guides covering (a) relevant considerations regarding professional and ethical conduct, and (b) the analysis steps for the STA130 course project that are feasible at the current stage of the course
#
# <br>
# <details class="details-example"><summary style="color:blue"><u>Ethical Professionalism Considerations</u></summary>
#
# ### Ethical Professionalism Considerations
#
# The TUT and HW both addressed some of the assumptions used in **Simple Linear Regression**. The **p-values** provided by `statsmodels` via `smf.ols(...).fit()` depend on these assumptions, so if they are not (at least approximately) correct, the **p-values** (and any subsequent claims regarding the "evidience against" the **null hypothesis**) are not reliable. In light of this consideration, describe how you could diagnostically check the first three assumptions (given below) when using analyses based on **Simple Linear regression** model. From an Ethical and Professional perspective, do you think doing diagnostic checks on the assumptions of a **Simple Linear regression** model is something you can and should do whenever you're doing this kind of analysis?
#
# > The first three assumptions associated with the **Simple Linear regression** model are that
# >
# > - the $\epsilon_i$ **errors** (sometimes referred to as the **noise**) are **normally distributed**
# > - the $\epsilon_i$ **errors** are **homoscedastic** (so their distributional variance $\sigma^2$ does not change as a function of $x_i$)
# > - the linear form is [at least reasonably approximately] "true" (in the sense that the above two remain [at least reasonably approximately] "true") so that then behavior of the $Y_i$ **outcomes** are represented/determined on average by the **linear equation**)<br>
# >
# >    and there are additional assumptions; but, a deeper reflection on these is "beyond the scope" of STA130; nonetheless, they are that<br><br>
# > - the $x_i$ **predictor variable** is **measured without error**
# > - and the $\epsilon_i$ **errors** are **statistically independent** (so their values do not depend on each other)
# > - and the $\epsilon_i$ **errors** are **unbiased** relative to the **expected value** of **outcome** $E[Y_i|x_i]=\beta_0 + \beta_1x_i$ (which is equivalently stated by saying that the mean of the **error distribution** is $0$, or again equivalently, that the **expected value** of the **errors** $E[\epsilon_i] = 0$)
#
# </details>
#
# <details class="details-example"><summary style="color:blue"><u>Current Course Project Capability Level</u></summary>
#
# **Remember to abide by the [data use agreement](https://static1.squarespace.com/static/60283c2e174c122f8ebe0f39/t/6239c284d610f76fed5a2e69/1647952517436/Data+Use+Agreement+for+the+Canadian+Social+Connection+Survey.pdf) at all times.**
#
# Information about the course project is available on the course github repo [here](https://github.com/pointOfive/stat130chat130/tree/main/CP), including a draft [course project specfication](https://github.com/pointOfive/stat130chat130/blob/main/CP/STA130F23_course_project_specification.ipynb) (subject to change).
# - The Week 01 HW introduced [STA130F24_CourseProject.ipynb](https://github.com/pointOfive/stat130chat130/blob/main/CP/STA130F24_CourseProject.ipynb), and the [available variables](https://drive.google.com/file/d/1ISVymGn-WR1lcRs4psIym2N3or5onNBi/view).
# - Please do not download the [data](https://drive.google.com/file/d/1mbUQlMTrNYA7Ly5eImVRBn16Ehy9Lggo/view) accessible at the bottom of the [CSCS](https://casch.org/cscs) webpage (or the course github repo) multiple times.
#
# > ### NEW DEVELOPMENT<br>New Abilities Achieved and New Levels Unlocked!!!
# > **As noted, the Week 01 HW introduced the [STA130F24_CourseProject.ipynb](https://github.com/pointOfive/stat130chat130/blob/main/CP/STA130F24_CourseProject.ipynb) notebook.** _And there it instructed students to explore the notebook through the first 16 cells of the notebook._ The following cell in that notebook (there marked as "run cell 17") is preceded by an introductory section titled, "**Now for some comparisons...**", _**and all material from that point on provides an example to allow you to start applying what you're learning about Hypothesis Testing to the CSCS data**_ **using a paired samples ("one sample") framework.**
# >
# > **NOW, HOWEVER, YOU CAN DO MORE.**
# > - _**Now you can do "two sample" hypothesis testing without the need for paired samples.**_ All you need are two groups.
# > - _**And now you can do simple linear regression modeling.**_ All you need are two columns.
#
# ### Current Course Project Capability Level
#
# At this point in the course you should be able to do a **Simple Linear Regression** analysis for data from the Canadian Social Connection Survey data
#
# 1. Create and test a **null hypothesis** of no linear association "on average" for a couple of columns of interest in the Canadian Social Connection Survey data using **Simple Linear Regression**
#
# 2. Use the **residuals** of a fitted **Simple Linear Regression** model to diagnostically assess some of the assumptions of the analysis
#
# 3. Use an **indicator variable** based **Simple Linear Regression** model to compare two groups from the Canadian Social Connection Survey data
#
# 4. Compare and contrast the results of an **indicator variable** based **Simple Linear Regression** model to analyses based on a **permutation test** and a **bootstrapped confidence interval**
#
# </details>
