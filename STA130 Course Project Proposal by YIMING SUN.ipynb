# %% [markdown]
# ### Research Question 1: *Does the amount of time spent on social media per day influence life satisfaction levels?*
#
# <div style="font-family: 'Arial'; font-size: 12px;">
#
# <font color='red'>**1. Variables**:</font>\
# **1.1 Types of Variables:  All Ordinal Data**\
# Independent variable: CONNECTION_social_media_time_per_day – Ordinal variable representing the amount of time spent on social media daily, with categories like “Less than 10 minutes,” “10-30 minutes,” “31-60 minutes,” “1-2 hours,” “2-3 hours,” and “More than 3 hours.”\
# Dependent variable: WELLNESS_life_satisfaction – Ordinal variable representing life satisfaction scores on a scale from 1 to 10, where higher scores indicate greater life satisfaction.\
# **1.2 Significance of those variables in my reserch question**:\
# This analysis helps identify whether higher or lower social media usage is linked to differences in life satisfaction. Understanding this relationship can offer insights into how social media habits impact overall wellbeing and life satisfaction.\
# **1.3 Data Preprocessing**:\
# WELLNESS_life_satisfaction, being on a continuous scale from 1 to 10, can be categorized into broader levels (e.g., “Low,” “Medium,” and “High” satisfaction) to make it suitable for ordinal analysis. The most important step is to use pd.cut().
# <font color='red'>**2. Visualizations**:</font>\
# **2.1 Bar Plot**:\
# Create a bar plot showing the average life satisfaction score for each category of social media usage. This plot will provide an overview of how life satisfaction scores vary with different levels of social media time.\
# **2.2 Box Plot**:\
# A box plot will display the distribution of life satisfaction scores across social media usage categories, allowing us to observe variability and identify any outliers within each group.\
# **2.3 KDE Plot**:\
# A Kernel Density Estimate (KDE) plot can help visualize the distribution of life satisfaction scores within each social media usage category, showing where values are concentrated, which adds depth to the understanding of differences across categories.
# <font color='red'>**3. Analysis: Chi-Square Test for Independence**</font>\
# 3.1 Set up a contingency table\
# 3.2 Set Up the Hypotheses** (which will be explored in 5)\
# 3.3 Perform the Chi-Square Test: by using scipy.stats.chi2_contingency\
# 3.4 Result Analysis: Analyze Chi-Square Statistic, p-value, Degrees of Freedom, and Expected Frequencies.\
# **3.5 Another possible analysis could be using f-stat hypothesis testing when life satisfaction is regarded as continuous data**\
# <font color='red'>**4. Assumptions**:</font>\
# **4.1 Independence of Observations: Each individual should only appear in one cell of the contingency table.** \
# **4.2 Adequate Sample Size: Expected frequency in each cell should ideally be at least 5.** \
# **4.3 Mutually Exclusive Categories: Each category should be distinct and non-overlapping.** \
# **4.4 Ordinal Data: Both variables should be categorical.** \
# **4.5 Random Sampling: Ideally, data should be collected randomly to ensure generalizability.** \
# <font color='red'>**5. Hypothesis**:</font>\
# **5.1 Null Hypothesis (H0)**: There is no association between social media usage time per day and life satisfaction. The distribution of life satisfaction scores is independent of social media usage categories.\
# **5.2 Alternative Hypothesis (H1)**: There is an association between social media usage time per day and life satisfaction, suggesting that the amount of time spent on social media influences life satisfaction levels.\
# <font color='red'>**6. Possible Outcomes (link to hypothesis with research question)**:</font>\
# If p < 0.05: Reject the null hypothesis. This suggests a statistically significant association between social media usage time and life satisfaction, implying that time spent on social media may impact life satisfaction.\
# If p > 0.05: Fail to reject the null hypothesis. This suggests no significant association between social media usage time and life satisfaction, indicating that the two variables are independent.
# </div>

# %% [markdown]
# ### Research Question 2: *Does age influence life satisfaction differently based on change in financial wellbeing?*
# <div style="font-family: 'Arial'; font-size: 12px;">
#
# <font color='red'>**1. Variables**:</font>\
# **1.1 Types of Variables:  All Continuous Data**\
# Independent variable: Age (DEMO_age)\
# Dependent variable: Life satisfaction score (WELLNESS_life_satisfaction)\
# Moderator variable: Financial wellbeing score (FINANCES_cfpb_financial_wellbeing_scale_score)\
# **1.2 Significance of those variables in my reserch question**:\
# This analysis helps reveal whether financial security serves as a buffer or enhancer of life satisfaction as people age.\
# <font color='red'>**2. Visualizations**:</font>\
# **2.1 Scatter Plot: Age vs. Life Satisfaction, Color-Coded by Financial Wellbeing**:A scatter plot is ideal for visualizing relationships between two continuous variables—in this case, age (x-axis) and life satisfaction (y-axis). ;**2.2  Box Plot: Life Satisfaction Across Different Age Groups, Segmented by Financial Wellbeing**: A box plot is used for comparing distributions across categories, making it suitable for examining the variability and central tendency of life satisfaction scores across different age groups.;**2.3 Heat Map: 3x3 Correlation Matrix of Age, Life Satisfaction, and Financial Wellbeing**:The heatmap provides a intuitive understanding of the strength and direction of relationships between variables. The correlation matrix will contain the pairwise correlation coefficients between each pair of variables. \
# <font color='red'>**3. Analysis: Multiple Linear Regression**</font>\
# **3.1 Set up a regression model,show followed**:\
# $ P(\text{Life Satisfaction}) = \beta_0 + \beta_1 \cdot X_1(\text{Age}) + \beta_2 \cdot X_2(\text{Financial Wellbeing}) + \beta_3 \cdot X_3(\text{Age} \times \text{Financial Wellbeing}) + \epsilon $\
# **3.2 Mean-Center the Variables: reducing multicollinearity**\
# df['Age_centered'] = df['DEMO_age'] - df['DEMO_age'].mean();\
# df['FinancialWellbeing_centered'] = df['FINANCES_cfpb_financial_wellbeing_scale_score'] -  df['FINANCES_cfpb_financial_wellbeing_scale_score'].mean()
# **3.3 Model Fit and Diagnostics: R-squared analysis and residual plot**\
# <font color='red'>**4. Assumptions**:</font>\
# **4.1. Linearity**: The relationship between age and life satisfaction, moderated by financial wellbeing, is approximately linear.\
# **4.2. Independence**: Observations are independent of one another, meaning each respondent's life satisfaction score is not influenced by others in the dataset.\
# **4.3. Homoscedasticity**: The variance of the residuals is constant across levels of the independent variables. This can be checked by plotting residuals against fitted values.\
# **4.4. Normality of Residuals**: The residuals of the regression model are normally distributed.\
# **4.5. No Multicollinearity**: The predictor variables (age, financial wellbeing, and their interaction term) are not excessively correlated with each other.\
# **4.6. Age vs. lifesatisfaction**: Age has effect on life satisfaction, which means β1≠0.\
# <font color='red'>**5. Hypothesis**:</font>\
# **5.1. Null Hypothesis (H0)**: \
# Financial wellbeing does not moderate the relationship between age and life satisfaction. This means that β3=0.\
# **5.2. Alternative Hypothesis (H1)**: \
# Financial wellbeing moderates the relationship between age and life satisfaction, such that 𝛽3≠0\
# <font color='red'>**6. Possible Outcomes(link to hypothesis with research question)**:</font>
# * 6.1 Interpretation if p < 0.05 for Interaction:
# The interaction between age and financial wellbeing was statistically significant (p < 0.05), indicating that the relationship between age and life satisfaction varies depending on financial wellbeing.
# * 6.2 Interpretation if p > 0.05 for Interaction:
# The interaction between age and financial wellbeing was not statistically significant (p > 0.05), suggesting that the relationship between age and life satisfaction does not vary based on financial wellbeing.
#     </div>

# %% [markdown]
# ### Research Question 3: *Is there an association between individuals' concerns about money and the number of hours they work per week?*
# <div style="font-family: 'Arial'; font-size: 12px;">
#
# <font color='red'>**1. Variables**:</font>\
# **1.1 Types of Variables: All Ordinal Data**\
# Independent variable: FINANCES_money_concerned – Ordinal variable representing the level of concern about money, with categories like “Not at all,” “Very Little,” “Somewhat,” “Very Well,” and “Completely.”\
# Dependent variable: WORK_hours_per_week – Ordinal variable representing different categories of work hours per week, which could be grouped as “0-10 hours,” “11-20 hours,” “21-30 hours,” “31+ hours” to create ordinal categories for analysis.\
# **1.2 Significance of those variables in my reserch question**:
# If financial concerns are associated with increased work hours, this suggests that financial stress drives individuals to work more, potentially sacrificing personal time or wellbeing in the process. Understanding this can help us infer how financial wellbeing shapes lifestyle choices and work habits.\
# **1.3 Data Preprocessing**:Because WORK_hours_per_week contains a list of continuous data, I need to classify it into different categories. The most important step is to use pd.cut().\
# <font color='red'>**2. Visualizations**:</font>\
# **2.1 Stacked Bar Chart**:Create a stacked bar chart to show the distribution of work hours across different levels of financial concern. Each bar would represent a financial concern category and would be subdivided into the different work hour categories.\
# **2.2 Heat Map**:\
# Why this plot: The heatmap provides a clear visual indication of any association between financial concern levels and work hours. Instead of raw numbers, color intensity makes it easy to see which combinations are most common.\
# <font color='red'>**3. Analysis: Chi-Squared Test**</font>\
# **3.1 Set up a contingency table**\
# **3.2 Set Up the Hypotheses**(which will be explored in 5)\
# **3.3 Perform the Chi-Square Test**: by using scipy.stats.chi2_contingency\
# **3.4 Result analysis**: Chi-Square Statistic, P value, Degrees of Freedom and Expected Frequencies\
# <font color='red'>**4. Assumptions**:</font>\
# **4.1 Independence of Observations**: Each individual should only appear in one cell of the contingency table.\
# **4.2 Adequate Sample Size**: Expected frequency in each cell should ideally be at least 5.\
# **4.3 Mutually Exclusive Categories**: Each category should be distinct and non-overlapping.\
# **4.4 Ordinal Data**: Both variables should be categorical.\
# **4.5 Random Sampling**: Ideally, data should be collected randomly to ensure generalizability.\
# <font color='red'>**5. Hypothesis**:</font>\
# **5.1 Null Hypothesis (H0)**: There is no association between money concerns and work hours. In other words, the two variables are independent.\
# **5.2 Alternative Hypothesis (H1)**: There is an association between money concerns and work hours, suggesting that money concern levels may influence the amount of time people spend working each week.\
# <font color='red'>**6. Possible Outcomes(link to hypothesis with research question)**:</font>
# * If p < 0.05: Reject the null hypothesis. This suggests there is a statistically significant association between money concerns and work hours, implying that the level of financial concern may influence the amount of time individuals work per week.
# * If p > 0.05: Fail to reject the null hypothesis. This suggests there is no significant association between money concerns and work hours, indicating that the two variables are independent.
#         </div>
